# %% [markdown]
# # Game of War

# %%
import random

suits=("Hearts","Spades","Diamonds","Clubs")
ranks=('Ace','Two','Three','Four','Five','Six','Seven','Eight',
        'Nine','Ten','Jack','Queen','King')

# Dictionary of values
values={'Ace':1,'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,
        'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13}

# %%
class Card():
    # Attributes of a card (suit, rank, value)
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value=values[rank]
    
    def __str__(self):
        return(self.rank+" of "+self.suit)

# %%
class Deck():
    # Constructed using instances of the card class
    def __init__(self):
        self.full_deck=[]
        for i in suits:
            for j in ranks:
                self.full_deck.append(Card(i,j))

    # Shuffle Deck
    def shuffle(self):
        random.shuffle(self.full_deck)
        
    # Draw a card
    def draw(self):
        return self.full_deck.pop(0)

# %%
class Player():
    # Contains half a deck of cards
    def __init__(self,name):
        self.name=name
        self.hand=[]
    
    def remove_one(self):
        return self.hand.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards)==type([]):
            self.hand.extend(new_cards)
        else:
            self.hand.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.hand)} cards.'

# %% [markdown]
# ## Game Logic

# %%
# Initialize Deck
new_deck=Deck()
# Shuffle Deck
new_deck.shuffle()

# Ask for player names
player1=Player('\033[34m'+input("Who is the first player? ")+'\x1b[0m')
player2=Player('\033[35m'+input("Who is the second player? ")+'\x1b[0m')

# Deal the deck to the players
player1.add_cards(new_deck.full_deck[0:26])
player2.add_cards(new_deck.full_deck[26:52])
# Out:
# Who is the first player?  Jane
# Who is the second player?  John

# %%
#Actual Gameplay
while (len(player1.hand)>0) & (len(player2.hand)>0):
    # Draw one card from each player's hand:
    A=[player1.remove_one()]
    B=[player2.remove_one()]
    a=A[0]
    b=B[0]
    print(player1.name," vs ",player2.name)
    print(a,"vs",b)
    while a.value==b.value:
        print('\033[31m'+"Time for a tiebreaker!"+'\x1b[0m')
        print("Draw three more cards:")
        for i in range(0,3):
            if len(player1.hand)>0:
                A.append(player1.remove_one())
            if len(player2.hand)>0:
                B.append(player2.remove_one())
        a=A[-1]
        b=B[-1]
        print(a,"vs",b)
    if a.value>b.value:
        player1.add_cards(A)
        player1.add_cards(B)
        print(player1.name, "wins this round.")
    elif a.value<b.value:
        player2.add_cards(B)
        player2.add_cards(A)
        print("          ",player2.name, "wins this round.")
    print("\n")
# Out:
# Jane  vs  John
# Nine of Clubs vs Ace of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Clubs vs Queen of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Five of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Diamonds vs Three of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Ten of Diamonds vs Ten of Spades
# Time for a tiebreaker!
# Draw three more cards:
# King of Clubs vs Jack of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Spades vs Eight of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Clubs vs Eight of Spades
#            John wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Ace of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Diamonds vs Two of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Hearts vs Eight of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Three of Diamonds vs Nine of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Six of Spades vs Queen of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Two of Spades vs Three of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Seven of Spades vs Six of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Clubs vs Seven of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Ten of Clubs vs Two of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Clubs vs Four of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Hearts vs Ten of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Four of Clubs vs Four of Spades
# Time for a tiebreaker!
# Draw three more cards:
# Jack of Hearts vs Seven of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Diamonds vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Nine of Clubs vs Queen of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Ace of Clubs vs Six of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Three of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Spades vs Ace of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Diamonds vs Eight of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Spades vs Seven of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Five of Hearts vs Eight of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# King of Clubs vs Four of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Spades vs Nine of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Diamonds vs Three of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Diamonds vs Queen of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Spades vs Six of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Spades vs Three of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Eight of Clubs vs Two of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Seven of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Hearts vs Five of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Nine of Diamonds vs Ten of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Two of Clubs vs Three of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Seven of Spades vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Six of Hearts vs Five of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Clubs vs Queen of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Two of Hearts vs Nine of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Clubs vs Six of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Diamonds vs Ace of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Clubs vs Seven of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Eight of Diamonds vs Ace of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Diamonds vs Eight of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Hearts vs Five of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Spades vs Queen of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# King of Diamonds vs Six of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Hearts vs Five of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Hearts vs Ace of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Ten of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Clubs vs Nine of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Five of Spades vs Three of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Diamonds vs Two of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Ten of Diamonds vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Eight of Spades vs Seven of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Clubs vs Queen of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Hearts vs Ten of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Ten of Spades vs Nine of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Spades vs Two of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Diamonds vs Seven of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Diamonds vs Four of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Spades vs Eight of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Spades vs Two of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# King of Spades vs Queen of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Spades vs Four of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Eight of Clubs vs Nine of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Two of Spades vs Three of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Two of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Diamonds vs Ace of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Hearts vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Five of Diamonds vs Ten of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Clubs vs Ten of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Clubs vs Four of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Diamonds vs Four of Clubs
# Time for a tiebreaker!
# Draw three more cards:
# Ace of Spades vs Three of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Hearts vs Nine of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Hearts vs Eight of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# King of Diamonds vs Three of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Diamonds vs Two of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Hearts vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Five of Clubs vs Six of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Seven of Hearts vs Ten of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Ace of Hearts vs Five of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Four of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Hearts vs Three of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Spades vs Four of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Hearts vs Three of Spades
# Time for a tiebreaker!
# Draw three more cards:
# King of Clubs vs Eight of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Hearts vs Ace of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Spades vs Eight of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Clubs vs Five of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Spades vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Two of Hearts vs Nine of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Diamonds vs Six of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Clubs vs Five of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Spades vs Ten of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Eight of Hearts vs Seven of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Spades vs Five of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Diamonds vs Ace of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# King of Spades vs Queen of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Diamonds vs Nine of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Nine of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Clubs vs Two of Hearts
# Time for a tiebreaker!
# Draw three more cards:
# Jack of Clubs vs Two of Hearts
# Jane wins this round.

# %%
# Declare the winner
if len(player1.hand)>0:
    print ('\033[32m'+ player1.name," has won!" + '\x1b[0m')
elif len(player2.hand)>0:
    print ('\033[32m'+ player2.name," has won!" + '\x1b[0m')
# Out:
# Jane  has won!
