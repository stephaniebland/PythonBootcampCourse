# %% [markdown]
# # Game of War

# %%
import random

suits=("Hearts","Spades","Diamonds","Clubs")
ranks=('Ace','Two','Three','Four','Five','Six','Seven','Eight',
        'Nine','Ten','Jack','Queen','King')

# Dictionary of values
values={'Ace':1,'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,
        'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13}

# %%
class Card():
    # Attributes of a card (suit, rank, value)
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value=values[rank]
    
    def __str__(self):
        return(self.rank+" of "+self.suit)

# %%
class Deck():
    # Constructed using instances of the card class
    def __init__(self):
        self.full_deck=[]
        for i in suits:
            for j in ranks:
                self.full_deck.append(Card(i,j))

    # Shuffle Deck
    def shuffle(self):
        random.shuffle(self.full_deck)
        
    # Draw a card
    def draw(self):
        return self.full_deck.pop(0)

# %%
class Player():
    # Contains half a deck of cards
    def __init__(self,name):
        self.name=name
        self.hand=[]
    
    def remove_one(self):
        return self.hand.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards)==type([]):
            self.hand.extend(new_cards)
        else:
            self.hand.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.hand)} cards.'

# %% [markdown]
# ## Game Logic

# %%
# Initialize Deck
new_deck=Deck()
# Shuffle Deck
new_deck.shuffle()

# Ask for player names
player1=Player(input("Who is the first player? "))
player2=Player(input("Who is the second player? "))

# Deal the deck to the players
player1.add_cards(new_deck.full_deck[0:26])
player2.add_cards(new_deck.full_deck[26:52])
# Out:
# Who is the first player?  Jane
# Who is the second player?  John

# %%
#Actual Gameplay
while (len(player1.hand)>0) & (len(player2.hand)>0):
    # Draw one card from each player's hand:
    A=[player1.remove_one()]
    B=[player2.remove_one()]
    a=A[0]
    b=B[0]
    print(player1.name," vs ",player2.name)
    print(a,"vs",b)
    while a.value==b.value:
        print('\033[31m'+"Time for a tiebreaker!"+'\x1b[0m')
        print("Draw three more cards:")
        for i in range(0,3):
            if len(player1.hand)>0:
                A.append(player1.remove_one())
            if len(player2.hand)>0:
                B.append(player2.remove_one())
        a=A[-1]
        b=B[-1]
        print(a,"vs",b)
    if a.value>b.value:
        player1.add_cards(A)
        player1.add_cards(B)
        print(player1.name, "wins this round.")
    elif a.value<b.value:
        player2.add_cards(B)
        player2.add_cards(A)
        print("          ",player2.name, "wins this round.")
    print("\n")
# Out:
# Jane  vs  John
# Four of Hearts vs Ten of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Jack of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Clubs vs Eight of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# King of Diamonds vs Three of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Spades vs Three of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Clubs vs Jack of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Two of Spades vs Ten of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# King of Spades vs Nine of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Diamonds vs Seven of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Three of Diamonds vs Seven of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# Queen of Hearts vs Two of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# King of Clubs vs Nine of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Ace of Hearts vs Six of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Six of Hearts vs Jack of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Ten of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Diamonds vs Five of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Spades vs Eight of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Eight of Spades vs Seven of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Diamonds vs Ace of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Clubs vs Nine of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Eight of Clubs vs Two of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Spades vs Three of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Hearts vs Seven of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Five of Spades vs Six of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Four of Diamonds vs Queen of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Ace of Diamonds vs Five of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Ten of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Diamonds vs Four of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# King of Diamonds vs Eight of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Clubs vs Ace of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Spades vs Jack of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Three of Spades vs Two of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# King of Spades vs Ten of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Diamonds vs Two of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Hearts vs Seven of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Diamonds vs Five of Diamonds
#            John wins this round.
#
#
# Jane  vs  John
# King of Clubs vs Seven of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Clubs vs Three of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Clubs vs Six of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Hearts vs Ace of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Six of Diamonds vs Jack of Clubs
#            John wins this round.
#
#
# Jane  vs  John
# Five of Hearts vs Six of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Nine of Spades vs Nine of Hearts
# Time for a tiebreaker!
# Draw three more cards:
# Seven of Hearts vs Five of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Diamonds vs Queen of Spades
# Time for a tiebreaker!
# Draw three more cards:
# Two of Hearts vs Ace of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Spades vs Jack of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Three of Hearts vs Ten of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Jack of Hearts vs Five of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Clubs vs Two of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# King of Hearts vs Jack of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Diamonds vs Six of Diamonds
# Jane wins this round.
#
#
# Jane  vs  John
# Jack of Diamonds vs Six of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Four of Hearts vs Five of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# King of Diamonds vs Jack of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Eight of Diamonds vs Four of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Three of Clubs vs Ten of Spades
#            John wins this round.
#
#
# Jane  vs  John
# Ace of Clubs vs Three of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Three of Spades vs Five of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# Two of Clubs vs Four of Hearts
#            John wins this round.
#
#
# Jane  vs  John
# King of Spades vs Ten of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# Ten of Clubs vs Three of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Nine of Diamonds vs Three of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Two of Spades vs Ace of Clubs
# Jane wins this round.
#
#
# Jane  vs  John
# Queen of Hearts vs Five of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Spades vs Three of Spades
# Jane wins this round.
#
#
# Jane  vs  John
# King of Clubs vs Four of Hearts
# Jane wins this round.
#
#
# Jane  vs  John
# Seven of Diamonds vs Two of Clubs
# Jane wins this round.

# %%
# Declare the winner
if len(player1.hand)>0:
    print ('\033[32m'+ player1.name," has won!" + '\x1b[0m')
elif len(player2.hand)>0:
    print ('\033[32m'+ player2.name," has won!" + '\x1b[0m')
# Out:
# Jane  has won!
